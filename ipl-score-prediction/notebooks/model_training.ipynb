# %% [markdown]
# # IPL score model training
#
# Run the reusable trainer from the project source folder after placing the historical CSV in `data/`.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent / 'src'))
from train_model import train
train('../data/ipl_ball_by_ball.csv')
